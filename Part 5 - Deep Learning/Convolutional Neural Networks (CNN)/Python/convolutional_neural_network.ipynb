# %% [markdown]
# # Convolutional Neural Network

# %% [markdown]
# ### Importing the libraries

# %%
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator

# %%
tf.__version__
# Out:
# '2.15.0'

# %% [markdown]
# ## Part 1 - Data Preprocessing

# %%
# prompt: mountt drive

from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ### Preprocessing the Training set

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                   shear_range=0.2,
                                   zoom_range=0.2,
                                   horizontal_flip=True)

# Ensure the path is correct and matches what was listed
training_set = train_datagen.flow_from_directory('C:/dataset/training_set',
                                                 target_size=(64, 64),
                                                 batch_size=32,
                                                 class_mode='binary')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-9409e3a55a99> in <cell line: 7>()
#       5
#       6 # Ensure the path is correct and matches what was listed
# ----> 7 training_set = train_datagen.flow_from_directory('C:/dataset/training_set',
#       8                                                  target_size=(64, 64),
#       9                                                  batch_size=32,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/preprocessing/image.py in flow_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio)
#    1647             and `y` is a numpy array of corresponding labels.
#    1648         """
# -> 1649         return DirectoryIterator(
#    1650             directory,
# ...

# %%
import os

parent_dir = 'C:/dataset'
print(os.listdir(parent_dir))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-e16e16ef8c74> in <cell line: 4>()
#       2
#       3 parent_dir = 'C:/dataset'
# ----> 4 print(os.listdir(parent_dir))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/dataset'

# %% [markdown]
# ### Preprocessing the Test set

# %%
test_datagen = ImageDataGenerator(rescale=1./255)
test_set = test_datagen.flow_from_directory('C:/dataset/test_set',
                                            target_size=(64, 64),
                                            batch_size=32,
                                            class_mode='binary')

# %% [markdown]
# ## Part 2 - Building the CNN

# %% [markdown]
# ### Initialising the CNN

# %%
cnn = tf.keras.models.Sequential()

# %% [markdown]
# ### Step 1 - Convolution

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu', input_shape=[64, 64, 3]))

# %% [markdown]
# ### Step 2 - Pooling

# %%
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# ### Adding a second convolutional layer

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# ### Step 3 - Flattening

# %%
cnn.add(tf.keras.layers.Flatten())

# %% [markdown]
# ### Step 4 - Full Connection

# %%
cnn.add(tf.keras.layers.Dense(units=128, activation='relu'))

# %% [markdown]
# ### Step 5 - Output Layer

# %%
cnn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %% [markdown]
# ## Part 3 - Training the CNN

# %% [markdown]
# ### Compiling the CNN

# %%
cnn.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### Training the CNN on the Training set and evaluating it on the Test set

# %%
cnn.fit(x=training_set, validation_data=test_set, epochs=25)

# %% [markdown]
# ## Part 4 - Making a single prediction

# %%
import numpy as np
from keras.preprocessing import image
test_image = image.load_img('C:/dataset/single_prediction/cat_or_dog_1.jpg', target_size = (64, 64))
test_image.show()
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = cnn.predict(test_image)
training_set.class_indices
print(result)
if result[0][0] == 1:
  prediction = 'dog'
else:
  prediction = 'cat'

print(prediction)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-375acbdf4906> in <cell line: 2>()
#       1 import numpy as np
# ----> 2 from keras.preprocessing import image
#       3 test_image = image.load_img('C:/dataset/single_prediction/cat_or_dog_1.jpg', target_size = (64, 64))
#       4 test_image.show()
#       5 test_image = image.img_to_array(test_image)
#
# /usr/local/lib/python3.10/dist-packages/keras/__init__.py in <module>
#       1 """AUTOGENERATED. DO NOT EDIT."""
#       2
# ----> 3 from keras import __internal__
#       4 from keras import activations
#       5 from keras import applications
#
# /usr/local/lib/python3.10/dist-packages/keras/__internal__/__init__.py in <module>
#       1 """AUTOGENERATED. DO NOT EDIT."""
#       2
# ----> 3 from keras.__internal__ import backend
#       4 from keras.__internal__ import layers
# ...

# %%
cnn.predict(x=test_set)
